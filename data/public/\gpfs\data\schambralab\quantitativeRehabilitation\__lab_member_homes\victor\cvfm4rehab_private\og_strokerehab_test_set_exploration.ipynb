# %%
import matplotlib.pyplot as plt

import pandas as pd


df = pd.read_csv("/gpfs/data/schambralab/quantitativeRehabilitation/__lab_member_homes/victor/cvfm4rehab/data/public/cleaned_metadata.csv")

# %%
df.head()
# Out:
#                     id  is_in_strokerehab_test_set  \
# 0    S00027_feeding1_1                       False
# 1    S00027_combing1_2                       False
# 2    S00027_glasses1_1                       False
# 3  S00027_face wash3_2                       False
# 4    S00027_glasses5_2                       False
#
#                            path_v patient  stroke   activity   fps  height  \
# 0    S00027/S00027_feeding1_1.avi  S00027    True    feeding  60.0     352
# 1    S00027/S00027_combing1_2.avi  S00027    True    combing  60.0     352
# 2    S00027/S00027_glasses1_1.avi  S00027    True    glasses  60.0     352
# 3  S00027/S00027_face wash3_2.avi  S00027    True  face wash  60.0     352
# 4    S00027/S00027_glasses5_2.avi  S00027    True    glasses  60.0     352
#
#    width  duration_s                          path_l  nlabels  \
# 0    736      70.500    S00027/S00027_feeding1_1.csv     4231
# 1    736      19.183    S00027/S00027_combing1_2.csv     1152
# ...

# %%
df = df[df['is_in_strokerehab_test_set']]

# %%
# Which activities?
print(df['activity'].unique())
# Which patients?
print(df['patient'].unique())
# Out:
# ['face wash' 'shelf right side' 'feeding' 'glasses' 'brushing' 'combing'
#  'shelf left side' 'drinking' 'RTT left side' 'deodrant' 'RTT right side']
# ['S00047' 'S00044' 'S00042' 'S00039' 'S0004' 'S00017' 'S00037' 'S00026']

# %%
# s47=mild, s44=moderate, s42=mild, s39=moderate, s4=moderate, s17=moderate, s37=mild, s26=mild

# %%
df[(df['activity'] == 'face wash') & (df['patient'] == 'S00047')]
# Out:
#                       id  is_in_strokerehab_test_set  \
# 922  S00047_face wash3_1                        True
# 938  S00047_face wash2_2                        True
# 951  S00047_face wash5_2                        True
# 955  S00047_face wash2_1                        True
# 957  S00047_face wash1_1                        True
# 960  S00047_face wash5_1                        True
# 961  S00047_face wash4_2                        True
# 967  S00047_face wash3_2                        True
# 968  S00047_face wash4_1                        True
# 997  S00047_face wash1_2                        True
#
#                              path_v patient  stroke   activity   fps  height  \
# 922  S00047/S00047_face wash3_1.mkv  S00047    True  face wash  60.0     704
# 938  S00047/S00047_face wash2_2.mkv  S00047    True  face wash  60.0     704
# 951  S00047/S00047_face wash5_2.mkv  S00047    True  face wash  60.0    1088
# ...

# %%
df['id'].tolist()
# Out:
# ['S00027_feeding1_1',
#  'S00027_combing1_2',
#  'S00027_glasses1_1',
#  'S00027_face wash3_2',
#  'S00027_glasses5_2',
#  'S00027_drinking5_2',
#  'S00027_brushing2_2',
#  'S00027_feeding4_2',
#  'S00027_glasses5_1',
#  'S00027_glasses4_2',
#  'S00027_combing2_2',
#  'S00027_combing4_2',
#  'S00027_brushing4_2',
#  'S00027_combing2_1',
#  'S00027_feeding4_1',
#  'S00027_brushing1_2',
#  'S00027_feeding5_2',
#  'S00027_glasses1_2',
#  'S00027_feeding2_1',
#  'S00027_face wash4_1',
#  'S00027_brushing5_2',
#  'S00027_combing3_2',
#  'S00027_drinking2_1',
#  'S00027_deodrant1_1',
#  'S00027_face wash4_2',
#  'S00027_deodrant5_1',
#  'S00027_drinking3_2',
#  'S00027_glasses3_1',
#  'S00027_face wash5_1',
#  'S00027_face wash5_2',
#  'S00027_face wash3_1',
#  'S00027_shelf left side2_1',
#  'S00027_drinking4_1',
#  'S00027_brushing2_1',
#  'S00027_RTT left side1_1',
#  'S00027_drinking4_2',
#  'S00027_deodrant3_2',
#  'S00027_RTT left side2_1',
#  'S00027_drinking1_1',
# ...
